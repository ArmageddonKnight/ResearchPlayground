# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

# %%
def hp(level, base_points):
    return (140 * 2 + 31 + base_points / 4) * level / 100 + 10 + level


def defense(level, base_points, modifier=1.0):
    return ((95 * 2 + 31 + base_points / 4) * level / 100 + 5) * modifier


def damage(level, attack, defense):
    return ((2 * level + 10) / 250) * attack / defense + 2

# %%
level = 100

defense_base_points = np.array(range(1, 129))

eternatus_hp_remained = []

ability_powers = [60, 80, 100, 120, 140, 160]
ability_powers = [200]

for power in ability_powers:
    attack = 300 * power
    # attack = np.array(range(100, 30100, 100))
    # defense_base_points, attack = np.meshgrid(defense_base_points, attack)

    hp_base_points = np.array([(252 - 2 * pts) for pts in defense_base_points])
    eternatus_defense = defense(level, defense_base_points)
    eternatus_hp = hp(level, hp_base_points)
    eternatus_damage = damage(level, attack, eternatus_defense)
    eternatus_hp_remained.append((eternatus_hp - eternatus_damage) / eternatus_hp)

# %%
plt.figure()

for i, power in enumerate(ability_powers):
    plt.plot(defense_base_points, eternatus_hp_remained[i])

plt.show()

# %%
import matplotlib.pyplot as plt
import torch


C_HP_SPECIES_STRENGTH = 130
C_DEFENSE_SPECIES_STRENGTH = 80
C_SPECIAL_DEFENSE_SPECIES_STRENGTH = 95


class DamageCalculator(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.defense_base_points = torch.nn.Parameter(torch.zeros(1))
        self.special_defense_base_points = torch.nn.Parameter(torch.zeros(1))

    def _damage(self, species_strength, base_points, attack):
        defense = (
            (species_strength * 2 + 31 + base_points / 4) * level / 100 + 5
        ) * modifier
        return (2 * level + 10) / 250 * attack / defense + 2

    def forward(self, level, attack, modifier):
        hp_base_points = (
            256
            - torch.clamp(self.defense_base_points, min=0, max=252)
            - torch.clamp(self.special_defense_base_points, min=0, max=252)
        )
        hp = (
            (C_HP_SPECIES_STRENGTH * 2 + 31 + hp_base_points / 4) * level / 100
            + 10
            + level
        )
        return (
            self._damage(C_DEFENSE_SPECIES_STRENGTH, self.defense_base_points, attack)
            + self._damage(
                C_SPECIAL_DEFENSE_SPECIES_STRENGTH,
                self.special_defense_base_points,
                attack,
            )
        ) / hp


ability_powers = list(range(60, 1500, 40))

plt.figure()


def _plot_optimal_defense_points(level, modifier):
    optimal_defense_points = []
    optimal_special_defense_points = []

    for power in ability_powers:
        calculator = DamageCalculator()
        optimizer = torch.optim.SGD(calculator.parameters(), lr=1e3)

        def _update():
            optimizer.zero_grad()
            loss = calculator(level, 3 * level * power, modifier)
            loss.backward()

            orig_defense_base_points = torch.clone(
                calculator.defense_base_points[0].detach()
            )
            orig_special_defense_base_points = torch.clone(
                calculator.special_defense_base_points[0].detach()
            )

            optimizer.step()

            updated_defense_base_points = calculator.defense_base_points[0]
            updated_special_defense_base_points = (
                calculator.special_defense_base_points[0]
            )

            return (
                abs(orig_defense_base_points - updated_defense_base_points).detach()
                + abs(
                    orig_special_defense_base_points
                    - updated_special_defense_base_points
                ).detach()
            )

        for _ in range(int(1e3)):
            if _update() < 2e-4:
                break

        optimal_defense_points.append(
            torch.clone(calculator.defense_base_points[0].detach())
        )
        optimal_special_defense_points.append(
            torch.clone(calculator.special_defense_base_points[0].detach())
        )

    print(
        "Optimal Defense Points:",
        optimal_defense_points,
        optimal_special_defense_points,
    )

    plt.plot(
        ability_powers,
        optimal_defense_points,
        label=f"lvl={level}, modifier={modifier}",
    )

    plt.plot(
        ability_powers,
        optimal_special_defense_points,
        linestyle="--",
        label=f"lvl={level}, modifier={modifier}",
    )


for level in [50, 100]:
    for modifier in [1.0, 1.5, 2.0]:
        _plot_optimal_defense_points(level, modifier)

plt.legend()
plt.grid(linestyle="-.", linewidth=1)
plt.show()
# Out:
# Optimal Defense Points: [tensor(27.3286), tensor(44.0735), tensor(56.8049), tensor(66.5623), tensor(74.0852), tensor(79.9131), tensor(84.4457), tensor(87.9829), tensor(90.7522), tensor(92.9270), tensor(94.6404), tensor(95.9943), tensor(97.0683), tensor(97.9231), tensor(98.6066), tensor(99.1557), tensor(99.5990), tensor(99.9589), tensor(100.2530), tensor(100.4950), tensor(100.6957), tensor(100.8634), tensor(101.0047), tensor(101.1249), tensor(101.2279), tensor(101.3171), tensor(101.3950), tensor(101.4636), tensor(101.5245), tensor(101.5789), tensor(101.6281), tensor(101.6727), tensor(101.7135), tensor(101.7509), tensor(101.7853), tensor(101.8175)] [tensor(0.0945), tensor(0.1404), tensor(0.2165), tensor(0.3792), tensor(0.0635), tensor(0.3333), tensor(0.1420), tensor(0.4518), tensor(0.5311), tensor(0.3562), tensor(1.2386), tensor(0.6859), tensor(1.4340), tensor(0.4581), tensor(1.0316), tensor(1.6022), tensor(0.1176), tensor(0.4711), tensor(0.8460), tensor(1.1928), tensor(1.4734), tensor(1.7948), tensor(2.0896), tensor(2.3422), tensor(2.5671), tensor(2.8003), tensor(2.9789), tensor(3.0978), tensor(3.2217), tensor(3.3091), tensor(3.4126), tensor(3.4013), tensor(3.5425), tensor(3.4978), tensor(3.4072), tensor(3.4828)]
# Optimal Defense Points: [tensor(17.0046), tensor(30.4547), tensor(41.5951), tensor(50.8674), tensor(58.6147), tensor(65.1083), tensor(70.5655), tensor(75.1620), tensor(79.0412), tensor(82.3206), tensor(85.0974), tensor(87.4521), tensor(89.4517), tensor(91.1520), tensor(92.5999), tensor(93.8344), tensor(94.8886), tensor(95.7900), tensor(96.5621), tensor(97.2246), tensor(97.7937), tensor(98.2838), tensor(98.7066), tensor(99.0722), tensor(99.3891), tensor(99.6643), tensor(99.9038), tensor(100.1132), tensor(100.2966), tensor(100.4578), tensor(100.5999), tensor(100.7257), tensor(100.8374), tensor(100.9369), tensor(101.0261), tensor(101.1061)] [tensor(0.0291), tensor(0.0777), tensor(0.0757), tensor(0.2500), tensor(0.2493), tensor(0.0165), tensor(0.3326), tensor(0.3556), tensor(0.0760), tensor(0.2922), tensor(0.3569), tensor(0.2546), tensor(0.0107), tensor(0.6982), tensor(0.1992), tensor(0.7836), tensor(0.0455), tensor(0.5317), tensor(1.0651), tensor(-0.0305), tensor(0.3687), tensor(0.7432), tensor(1.1277), tensor(1.5682), tensor(1.8635), tensor(0.1576), tensor(0.4032), tensor(0.6362), tensor(0.9113), tensor(1.1447), tensor(1.3578), tensor(1.5295), tensor(1.7497), tensor(1.9199), tensor(2.1390), tensor(2.2731)]
# Optimal Defense Points: [tensor(11.2525), tensor(22.3522), tensor(31.9634), tensor(40.3127), tensor(47.5856), tensor(53.9354), tensor(59.4900), tensor(64.3573), tensor(68.6286), tensor(72.3817), tensor(75.6835), tensor(78.5913), tensor(81.1545), tensor(83.4161), tensor(85.4133), tensor(87.1785), tensor(88.7397), tensor(90.1216), tensor(91.3459), tensor(92.4313), tensor(93.3941), tensor(94.2492), tensor(95.0091), tensor(95.6848), tensor(96.2864), tensor(96.8225), tensor(97.3004), tensor(97.7272), tensor(98.1085), tensor(98.4496), tensor(98.7553), tensor(99.0294), tensor(99.2756), tensor(99.4969), tensor(99.6961), tensor(99.8757)] [tensor(0.0291), tensor(0.0056), tensor(0.1031), tensor(0.0166), tensor(0.1052), tensor(0.2870), tensor(0.0371), tensor(0.3183), tensor(0.3845), tensor(0.2243), tensor(0.5001), tensor(0.6678), tensor(0.7164), tensor(0.6475), tensor(0.4664), tensor(0.1608), tensor(0.7438), tensor(0.2680), tensor(0.7824), tensor(0.1208), tensor(0.5795), tensor(1.0354), tensor(0.1215), tensor(0.4865), tensor(0.8649), tensor(1.2338), tensor(0.0266), tensor(0.3042), tensor(0.5972), tensor(0.9027), tensor(1.1781), tensor(1.4769), tensor(1.7307), tensor(-0.0110), tensor(0.1869), tensor(0.3851)]
# Optimal Defense Points: [tensor(32.0832), tensor(48.7731), tensor(61.2897), tensor(70.7517), tensor(77.9460), tensor(83.4402), tensor(87.6510), tensor(90.8874), tensor(93.3813), tensor(95.3077), tensor(96.7990), tensor(97.9565), tensor(98.8571), tensor(99.5596), tensor(100.1096), tensor(100.5416), tensor(100.8823), tensor(101.1522), tensor(101.3673), tensor(101.5397), tensor(101.6787), tensor(101.7917), tensor(101.8843), tensor(101.9608), tensor(102.0246), tensor(102.0785), tensor(102.1242), tensor(102.1637), tensor(102.1979), tensor(102.2279), tensor(102.2546), tensor(102.2785), tensor(102.3001), tensor(102.3197), tensor(102.3377), tensor(102.3545)] [tensor(0.0720), tensor(0.1385), tensor(0.2129), tensor(0.2230), tensor(0.1948), tensor(0.4626), tensor(0.4775), tensor(0.2617), tensor(0.8779), tensor(0.2540), tensor(0.7151), tensor(1.1641), tensor(0.0014), tensor(0.2531), tensor(0.4972), tensor(0.7263), tensor(0.9284), tensor(1.1008), tensor(1.2396), tensor(1.3582), tensor(1.4571), tensor(1.5365), tensor(1.5835), tensor(1.5653), tensor(1.5215), tensor(1.5016), tensor(1.4250), tensor(1.3279), tensor(1.1909), tensor(1.1509), tensor(0.8798), tensor(0.7468), tensor(0.4555), tensor(0.4337), tensor(0.1684), tensor(4.0579)]
# Optimal Defense Points: [tensor(21.6875), tensor(35.2161), tensor(46.3178), tensor(55.4736), tensor(63.0543), tensor(69.3501), tensor(74.5926), tensor(78.9669), tensor(82.6235), tensor(85.6847), tensor(88.2511), tensor(90.4051), tensor(92.2151), tensor(93.7379), tensor(95.0200), tensor(96.1007), tensor(97.0127), tensor(97.7833), tensor(98.4348), tensor(98.9865), tensor(99.4542), tensor(99.8513), tensor(100.1889), tensor(100.4765), tensor(100.7219), tensor(100.9317), tensor(101.1115), tensor(101.2658), tensor(101.3987), tensor(101.5135), tensor(101.6129), tensor(101.6992), tensor(101.7744), tensor(101.8402), tensor(101.8980), tensor(101.9490)] [tensor(0.0498), tensor(0.0211), tensor(0.0679), tensor(0.1375), tensor(0.0494), tensor(0.0192), tensor(0.2691), tensor(0.3680), tensor(0.3069), tensor(0.0984), tensor(0.6071), tensor(0.1489), tensor(0.5709), tensor(0.9769), tensor(0.1676), tensor(0.4890), tensor(0.7952), tensor(1.0720), tensor(1.3790), tensor(0.0564), tensor(0.2166), tensor(0.3824), tensor(0.5410), tensor(0.6997), tensor(0.8246), tensor(0.9459), tensor(1.0736), tensor(1.1874), tensor(1.2502), tensor(1.3479), tensor(1.4071), tensor(1.4668), tensor(1.5072), tensor(1.5536), tensor(1.5819), tensor(1.5580)]
# Optimal Defense Points: [tensor(15.8648), tensor(27.0815), tensor(36.7254), tensor(45.0452), tensor(52.2427), tensor(58.4838), tensor(63.9062), tensor(68.6251), tensor(72.7375), tensor(76.3259), tensor(79.4605), tensor(82.2012), tensor(84.5997), tensor(86.7003), tensor(88.5413), tensor(90.1559), tensor(91.5728), tensor(92.8171), tensor(93.9103), tensor(94.8715), tensor(95.7169), tensor(96.4610), tensor(97.1163), tensor(97.6939), tensor(98.2032), tensor(98.6525), tensor(99.0493), tensor(99.3999), tensor(99.7099), tensor(99.9844), tensor(100.2275), tensor(100.4430), tensor(100.6343), tensor(100.8044), tensor(100.9557), tensor(101.0904)] [tensor(0.0022), tensor(0.0193), tensor(0.0562), tensor(0.1502), tensor(0.0194), tensor(0.2015), tensor(0.1679), tensor(0.4072), tensor(-0.0146), tensor(0.5520), tensor(0.4538), tensor(0.2414), tensor(0.6874), tensor(0.2905), tensor(0.6778), tensor(0.0921), tensor(0.4225), tensor(0.7268), tensor(1.0346), tensor(0.1345), tensor(0.3742), tensor(0.5968), tensor(0.8221), tensor(1.0428), tensor(1.2638), tensor(1.4843), tensor(0.0710), tensor(0.1999), tensor(0.3266), tensor(0.4474), tensor(0.5562), tensor(0.6940), tensor(0.7944), tensor(0.8683), tensor(0.9692), tensor(1.0632)]
