# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

# %%
def hp(level, base_points):
    return (140 * 2 + 31 + base_points / 4) * level / 100 + 10 + level


def defense(level, base_points, modifier=1.0):
    return ((95 * 2 + 31 + base_points / 4) * level / 100 + 5) * modifier


def damage(level, attack, defense):
    return ((2 * level + 10) / 250) * attack / defense + 2

# %%
level = 100

defense_base_points = np.array(range(1, 129))

eternatus_hp_remained = []

ability_powers = [60, 80, 100, 120, 140, 160]
ability_powers = [200]

for power in ability_powers:
    attack = 300 * power
    # attack = np.array(range(100, 30100, 100))
    # defense_base_points, attack = np.meshgrid(defense_base_points, attack)

    hp_base_points = np.array([(252 - 2 * pts) for pts in defense_base_points])
    eternatus_defense = defense(level, defense_base_points)
    eternatus_hp = hp(level, hp_base_points)
    eternatus_damage = damage(level, attack, eternatus_defense)
    eternatus_hp_remained.append((eternatus_hp - eternatus_damage) / eternatus_hp)

# %%
plt.figure()

for i, power in enumerate(ability_powers):
    plt.plot(defense_base_points, eternatus_hp_remained[i])

plt.show()

# %%
import matplotlib.pyplot as plt
import torch


C_HP_SPECIES_STRENGTH = 100
C_DEFENSE_SPECIES_STRENGTH = 110
C_SPECIAL_DEFENSE_SPECIES_STRENGTH = 100


class DamageCalculator(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.defense_base_points = torch.nn.Parameter(torch.zeros(1))
        self.special_defense_base_points = torch.nn.Parameter(torch.zeros(1))

    def _damage(self, species_strength, base_points, attack):
        defense = (
            (species_strength * 2 + 31 + base_points / 4) * level / 100 + 5
        ) * modifier
        return (2 * level + 10) / 250 * attack / defense + 2

    def forward(self, level, attack, modifier):
        hp_base_points = (
            256
            - torch.clamp(self.defense_base_points, min=0, max=252)
            - torch.clamp(self.special_defense_base_points, min=0, max=252)
        )
        hp = (
            (C_HP_SPECIES_STRENGTH * 2 + 31 + hp_base_points / 4) * level / 100
            + 10
            + level
        )
        return (
            self._damage(C_DEFENSE_SPECIES_STRENGTH, self.defense_base_points, attack)
            + self._damage(
                C_SPECIAL_DEFENSE_SPECIES_STRENGTH,
                self.special_defense_base_points,
                attack,
            )
        ) / hp


ability_powers = list(range(60, 1500, 40))

plt.figure()


def _plot_optimal_defense_points(level, modifier):
    optimal_defense_points = []
    optimal_special_defense_points = []

    for power in ability_powers:
        calculator = DamageCalculator()
        optimizer = torch.optim.SGD(calculator.parameters(), lr=1e3)

        def _update():
            optimizer.zero_grad()
            loss = calculator(level, 3 * level * power, modifier)
            loss.backward()

            orig_defense_base_points = torch.clone(
                calculator.defense_base_points[0].detach()
            )
            orig_special_defense_base_points = torch.clone(
                calculator.special_defense_base_points[0].detach()
            )

            optimizer.step()

            updated_defense_base_points = calculator.defense_base_points[0]
            updated_special_defense_base_points = (
                calculator.special_defense_base_points[0]
            )

            return (
                abs(orig_defense_base_points - updated_defense_base_points).detach()
                + abs(
                    orig_special_defense_base_points
                    - updated_special_defense_base_points
                ).detach()
            )

        for _ in range(int(1e3)):
            if _update() < 2e-4:
                break

        optimal_defense_points.append(
            torch.clone(calculator.defense_base_points[0].detach())
        )
        optimal_special_defense_points.append(
            torch.clone(calculator.special_defense_base_points[0].detach())
        )

    print(
        "Optimal Defense Points:",
        optimal_defense_points,
        optimal_special_defense_points,
    )

    plt.plot(
        ability_powers,
        optimal_defense_points,
        label=f"lvl={level}, modifier={modifier}",
    )

    plt.plot(
        ability_powers,
        optimal_special_defense_points,
        linestyle="--",
        label=f"lvl={level}, modifier={modifier}",
    )


for level in [50, 100]:
    for modifier in [1.0, 1.5, 2.0]:
        _plot_optimal_defense_points(level, modifier)

plt.legend()
plt.grid(linestyle="-.", linewidth=1)
plt.show()
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/torch/autograd/__init__.py:173: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:109.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Optimal Defense Points: [tensor(-0.0328), tensor(0.0881), tensor(-0.0030), tensor(0.1785), tensor(0.0882), tensor(-0.0197), tensor(0.3365), tensor(0.4368), tensor(0.2722), tensor(-0.1482), tensor(0.5953), tensor(-0.2292), tensor(0.3571), tensor(0.9379), tensor(-0.4279), tensor(-0.0122), tensor(0.4078), tensor(0.7926), tensor(1.1770), tensor(1.6079), tensor(1.8232), tensor(-0.5808), tensor(-0.3705), tensor(-0.1937), tensor(-0.0316), tensor(0.1422), tensor(0.2353), tensor(0.3790), tensor(0.4868), tensor(0.5478), tensor(0.6255), tensor(0.7036), tensor(0.7464), tensor(0.8048), tensor(0.7825), tensor(0.8788)] [tensor(-0.0248), tensor(0.0970), tensor(0.1348), tensor(0.2033), tensor(0.3858), tensor(0.6184), tensor(0.3281), tensor(0.5954), tensor(0.5733), tensor(0.2960), tensor(1.1485), tensor(0.4604), tensor(1.1658), tensor(0.0480), tensor(0.5711), tensor(1.1341), tensor(-0.2113), tensor(-0.1364), tensor(-0.0763), tensor(-0.0284), tensor(0.2626), tensor(0.5649), tensor(0.7903), tensor(0.9588), tensor(1.0563), tensor(1.2116), tensor(1.3120), tensor(1.3814), tensor(1.4140), tensor(1.3514), tensor(1.2698), tensor(1.2585), tensor(1.1642), tensor(0.8760), tensor(0.4566), tensor(-0.0202)]
# Optimal Defense Points: [tensor(0.0156), tensor(0.0259), tensor(0.1123), tensor(-0.0897), tensor(-0.0591), tensor(0.3966), tensor(-0.1048), tensor(0.3101), tensor(0.5519), tensor(0.6262), tensor(0.5317), tensor(0.2616), tensor(-0.1683), tensor(0.4209), tensor(-0.2759), tensor(0.2225), tensor(0.7077), tensor(-0.3371), tensor(0.0719), tensor(0.4504), tensor(0.8393), tensor(1.2018), tensor(-0.3503), tensor(-0.0643), tensor(0.1899), tensor(0.4699), tensor(0.7577), tensor(0.9882), tensor(1.2470), tensor(1.5837), tensor(1.6790), tensor(1.9088), tensor(-0.6263), tensor(-0.4837), tensor(-0.3386), tensor(-0.1975)] [tensor(0.0792), tensor(-0.0219), tensor(0.0225), tensor(0.2067), tensor(0.1612), tensor(0.3690), tensor(0.0757), tensor(0.0046), tensor(0.3510), tensor(0.5403), tensor(0.5531), tensor(0.3938), tensor(0.0666), tensor(0.7501), tensor(0.1438), tensor(0.7231), tensor(-0.1419), tensor(0.3397), tensor(0.8072), tensor(1.2788), tensor(-0.0418), tensor(0.3115), tensor(0.6682), tensor(1.0263), tensor(1.4178), tensor(-0.1968), tensor(-0.1482), tensor(-0.1063), tensor(-0.0674), tensor(-0.0359), tensor(-0.0075), tensor(0.2882), tensor(0.5311), tensor(0.6228), tensor(0.8191), tensor(0.9380)]
# Optimal Defense Points: [tensor(0.0568), tensor(0.0663), tensor(-0.0060), tensor(0.0910), tensor(0.2505), tensor(0.2041), tensor(0.1333), tensor(0.2243), tensor(0.0659), tensor(0.3238), tensor(0.4405), tensor(0.4357), tensor(0.3049), tensor(0.0482), tensor(0.6291), tensor(0.1808), tensor(0.6898), tensor(0.0512), tensor(0.4938), tensor(0.9284), tensor(0.0379), tensor(0.4111), tensor(0.7728), tensor(-0.3541), tensor(-0.0789), tensor(0.2172), tensor(0.4925), tensor(0.7891), tensor(1.0845), tensor(1.3450), tensor(-0.3157), tensor(-0.1120), tensor(0.1055), tensor(0.3049), tensor(0.5293), tensor(0.7014)] [tensor(0.0673), tensor(-0.0010), tensor(0.0157), tensor(0.2413), tensor(0.0551), tensor(0.2381), tensor(0.3904), tensor(0.1707), tensor(0.1702), tensor(0.5741), tensor(0.1339), tensor(0.2178), tensor(0.1761), tensor(0.0033), tensor(0.6703), tensor(0.2951), tensor(0.8812), tensor(0.3128), tensor(0.8640), tensor(0.0692), tensor(0.5038), tensor(0.9447), tensor(-0.0875), tensor(0.2808), tensor(0.6323), tensor(0.9847), tensor(1.3328), tensor(-0.0929), tensor(0.1940), tensor(0.4512), tensor(0.7125), tensor(0.9734), tensor(1.2349), tensor(1.6643), tensor(-0.1920), tensor(-0.1544)]
# Optimal Defense Points: [tensor(-0.0200), tensor(0.0650), tensor(0.1024), tensor(0.2612), tensor(-0.0945), tensor(-0.1480), tensor(0.4749), tensor(0.0151), tensor(0.4833), tensor(0.9580), tensor(-0.0675), tensor(0.2251), tensor(0.5024), tensor(0.7900), tensor(1.0934), tensor(1.2730), tensor(1.5043), tensor(1.6982), tensor(-0.5673), tensor(-0.5168), tensor(-0.4747), tensor(-0.4882), tensor(-0.5054), tensor(-0.5259), tensor(-0.5479), tensor(-0.5795), tensor(-0.6111), tensor(-0.6461), tensor(-0.7956), tensor(-0.9268), tensor(2.9018), tensor(2.9254), tensor(2.8463), tensor(2.7853), tensor(2.5952), tensor(2.6418)] [tensor(0.1326), tensor(0.1922), tensor(0.1361), tensor(-0.0585), tensor(0.3578), tensor(0.4988), tensor(0.3590), tensor(-0.0447), tensor(0.4501), tensor(0.9329), tensor(-0.0494), tensor(0.2491), tensor(0.5368), tensor(0.7974), tensor(1.0512), tensor(1.2668), tensor(1.5047), tensor(1.8226), tensor(-0.2477), tensor(-0.2559), tensor(-0.2659), tensor(-0.2803), tensor(-0.2985), tensor(-0.3200), tensor(2.5103), tensor(2.2560), tensor(2.0728), tensor(1.9910), tensor(1.7224), tensor(1.6219), tensor(1.3555), tensor(1.1080), tensor(0.9316), tensor(0.5975), tensor(0.2987), tensor(0.0448)]
# Optimal Defense Points: [tensor(0.0714), tensor(0.0443), tensor(0.0589), tensor(0.2104), tensor(0.3188), tensor(0.0987), tensor(0.1460), tensor(0.0322), tensor(0.5451), tensor(0.1664), tensor(0.5816), tensor(-0.0624), tensor(0.2527), tensor(0.5630), tensor(0.8691), tensor(-0.2235), tensor(-0.0191), tensor(0.1866), tensor(0.3657), tensor(0.5581), tensor(0.7373), tensor(0.9135), tensor(1.1153), tensor(1.2330), tensor(1.3861), tensor(1.5291), tensor(1.6680), tensor(1.7858), tensor(-0.5617), tensor(-0.5237), tensor(-0.4694), tensor(-0.4766), tensor(-0.4856), tensor(-0.4963), tensor(-0.5086), tensor(-0.5223)] [tensor(0.0449), tensor(0.0850), tensor(0.1264), tensor(0.1330), tensor(0.3903), tensor(0.3029), tensor(0.5016), tensor(0.5198), tensor(0.3602), tensor(0.0229), tensor(0.4718), tensor(0.9135), tensor(0.2039), tensor(0.5386), tensor(0.8572), tensor(1.1791), tensor(0.0036), tensor(0.2044), tensor(0.3990), tensor(0.5792), tensor(0.7447), tensor(0.9069), tensor(1.1009), tensor(1.2249), tensor(1.4306), tensor(1.5340), tensor(1.8047), tensor(-0.2461), tensor(-0.2479), tensor(-0.2536), tensor(-0.2603), tensor(-0.2680), tensor(-0.2776), tensor(-0.2890), tensor(-0.3019), tensor(-0.3162)]
# Optimal Defense Points: [tensor(0.0522), tensor(0.0513), tensor(0.0449), tensor(0.1840), tensor(0.1693), tensor(0.1881), tensor(-0.0480), tensor(0.0407), tensor(-0.0774), tensor(0.3740), tensor(0.0977), tensor(0.4819), tensor(0.0064), tensor(0.3240), tensor(0.6316), tensor(-0.1018), tensor(0.1377), tensor(0.3736), tensor(0.5986), tensor(0.8328), tensor(-0.3017), tensor(-0.1431), tensor(0.0088), tensor(0.1761), tensor(0.2959), tensor(0.4291), tensor(0.5681), tensor(0.7065), tensor(0.8566), tensor(0.9871), tensor(1.1251), tensor(1.2099), tensor(1.3288), tensor(1.4466), tensor(1.5470), tensor(1.6581)] [tensor(0.0382), tensor(0.0492), tensor(0.1266), tensor(0.2218), tensor(0.0350), tensor(0.1671), tensor(0.0417), tensor(0.2046), tensor(0.2220), tensor(0.1137), tensor(0.6014), tensor(0.2923), tensor(0.7021), tensor(0.1931), tensor(0.5263), tensor(0.8580), tensor(0.0783), tensor(0.3300), tensor(0.5799), tensor(0.8278), tensor(1.0588), tensor(-0.1302), tensor(0.0235), tensor(0.1841), tensor(0.3289), tensor(0.4637), tensor(0.5986), tensor(0.7218), tensor(0.8533), tensor(0.9737), tensor(1.1147), tensor(1.2080), tensor(1.3491), tensor(1.4662), tensor(1.5553), tensor(1.7945)]
